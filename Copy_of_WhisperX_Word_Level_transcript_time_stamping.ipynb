# %% [markdown]
# <a href="https://colab.research.google.com/github/vkyscen/whisperX-AI-trial/blob/main/Copy_of_WhisperX_Word_Level_transcript_time_stamping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Check GPU availability

# %%
# !nvidia-smi
# Out:
# Sat Jan 20 01:28:26 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # Install WhisperX

# %%
! pip install git+https://github.com/m-bain/whisperx.git
# Out:
# ...
#   Cloning https://github.com/m-bain/whisperx.git to /tmp/pip-req-build-j1_kb7sg
#   Running command git clone --filter=blob:none --quiet https://github.com/m-bain/whisperx.git /tmp/pip-req-build-j1_kb7sg
#   Resolved https://github.com/m-bain/whisperx.git to commit 8227807fa9e076901ea4b4fbbf79c9777a6f5e03
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/SYSTRAN/faster-whisper.git (to revision 0.10.0) to /tmp/pip-install-e4rbkhf8/faster-whisper_216de6605264447ba4c1792662ae7b19
#   Running command git clone --filter=blob:none --quiet https://github.com/SYSTRAN/faster-whisper.git /tmp/pip-install-e4rbkhf8/faster-whisper_216de6605264447ba4c1792662ae7b19
#   Running command git checkout -q e1a218fab1ab02d637b79565995bf1a9c4c83a09
#   Resolved https://github.com/SYSTRAN/faster-whisper.git to commit e1a218fab1ab02d637b79565995bf1a9c4c83a09
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# # Install Whisper

# %%
! pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-nddtla77
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-nddtla77
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %% [markdown]
# # Upload Input Audio / Video File

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-71d999da-dd1f-40b5-9add-411929ab341f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-71d999da-dd1f-40b5-9add-411929ab341f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Get SRT Subtitle File Saved using WhisperX

# %%
# !whisperx new_video.mp4 --model medium.en --output_dir . --align_model WAV2VEC2_ASR_LARGE_LV60K_960H --highlight_words True
# Out:
# 2024-01-20 01:37:53.631650: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-20 01:37:53.631716: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-20 01:37:53.633103: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-20 01:37:54.838401: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
# ...

# %% [markdown]
# # Converting Srt to Ass for word level subtitles

# %%
# !ffmpeg -i new_video.srt new_video.ass

# %% [markdown]
# # Burn the Ass Subtitle file to the Video

# %%
# !ffmpeg -i new_video.mp4 -vf "ass=new_video.ass" -c:v libx264 -preset slow -crf 18 new_video_out_slow_crf18.mkv
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
